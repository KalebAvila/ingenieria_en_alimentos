# %% [markdown]
# # Imports

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import warnings

from sklearn.decomposition import PCA
from numpy.linalg import norm

# %% [markdown]
# # Configuration

# %%
pd.set_option('display.max_rows', 2000)
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read data

# %%
edamam_flavor = pd.read_pickle('../data_discovery/edamam_flavor_dbs_nutrients.pkl')

# %% [markdown]
# # Functions

# %%
def cosine_similarity(w1, w2, base_df):
    A = base_df.loc[w1]
    B = base_df.loc[w2]
    cosine = np.dot(A,B)/(norm(A)*norm(B))
    return cosine

def jaccard_similarity(w1, w2, base_df):
    set1 = base_df.loc[w1].common_name
    set2 = molecules_per_entity_jaccard.loc[w2].common_name
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union

def get_top_similarities(w, base_df, similarity_metric='jaccard'):
    similarities = []
    words = graph_flavor_molecules_df[graph_flavor_molecules_df.entity_alias_readable!=w].entity_alias_readable.drop_duplicates()
    for entity in words:
        if similarity_metric == 'jaccard':
            similarities.append(jaccard_similarity(w, entity, base_df=base_df))
        elif similarity_metric == 'cosine':
            similarities.append(cosine_similarity(w, entity, base_df=base_df))
    response = pd.DataFrame({'entity':words, 'similarity':similarities})
    return  response.sort_values('similarity', ascending=False)

# %%
columns_defined = [
    'taste',
    'functional_groups',
    'fooddb_flavor_profile',
    'supersweetdb_id',
    'fooddb_id',
    'common_name',
    'bitterdb_id',
    'super_sweet',
    'flavornet_id',
    'pubchem_id',
    'bitter',
    'iupac_name',
    'odor',
    'smile',
    'inchi',
    'cas_id',
    'flavor_profile',
    'fema_flavor_profile',
]
flavor_molecules_df_list = []

nutrition_facts_df_list = []

for row_index in range(edamam_flavor.shape[0]):
    df_temporal_index = edamam_flavor.iloc[row_index]
    flavor_molecules_df = pd.DataFrame(df_temporal_index.molecules)
    flavor_molecules_df['entity_alias_readable'] = df_temporal_index.entity_alias_readable
    flavor_molecules_df_list.append(flavor_molecules_df)
    nutrition_facts_df = pd.DataFrame(df_temporal_index.nutritional_info).iloc[-1:]
    nutrition_facts_df['entity_alias_readable'] = df_temporal_index.entity_alias_readable
    nutrition_facts_df_list.append(nutrition_facts_df)
    
    
flavor_molecules = pd.concat(flavor_molecules_df_list)[columns_defined + ['entity_alias_readable']]
nutrition_facts = pd.concat(nutrition_facts_df_list).set_index("entity_alias_readable").fillna(0)

# %%
# Create graph
graph_flavor_molecules_df = flavor_molecules[['entity_alias_readable', 'common_name']]
graph_flavor_molecules_df['dummy'] = 1
graph_flavor_molecules = nx.from_pandas_edgelist(graph_flavor_molecules_df.rename(
    columns={'entity_alias_readable': 'source', 'common_name':'target'}
))

graph_flavor_molecules_df_vector = pd.get_dummies(graph_flavor_molecules_df.common_name)
graph_flavor_molecules_df_vector['entity_alias_readable'] = graph_flavor_molecules_df['entity_alias_readable']

# %%
molecules_per_entity = pd.pivot_table(
    graph_flavor_molecules_df, 
    index='entity_alias_readable',
    columns='common_name', 
    aggfunc='count', 
    values="dummy", 
    fill_value=0
)

molecules_per_entity_jaccard = pd.DataFrame(
    graph_flavor_molecules_df.groupby('entity_alias_readable').common_name.apply(lambda x: set(x))
)

# %%
flavor_pca_obj = PCA(
    n_components=100,
    copy=True, 
    whiten=False,
    svd_solver='auto',
    tol=0.0, 
    iterated_power='auto',
    n_oversamples=10,
    power_iteration_normalizer='auto', 
    random_state=99
)

flavor_per_entity_reduced = pd.DataFrame(flavor_pca_obj.fit_transform(molecules_per_entity), index=molecules_per_entity.index)

# %%
ingredients = pd.Series(flavor_per_entity_reduced.index)

# %%
ingredients[ingredients.str.contains("pear")]
# Out:
# 577        Spearmint
# 607    Tapioca pearl
# Name: entity_alias_readable, dtype: object

# %%
word = 'Oregano'
def get_similar_foods(word, consideration_of_elements=20):
    total_similitude = {
        'flavor': get_top_similarities(
            word, 
            similarity_metric='cosine', 
            #base_df=molecules_per_entity
            base_df=flavor_per_entity_reduced

        ).rename(columns={'entity':'flavor'}),
        'nutrients': get_top_similarities(
            word, 
            similarity_metric='cosine',
            base_df=nutrients_per_entity_reduced
            #base_df=nutrients_per_entity_reduced
        ).rename(columns={'entity':'nutrient'}),
    }

    comparison = pd.concat(
        [total_similitude['flavor'], total_similitude['nutrients']], axis=1
    ).head(consideration_of_elements)
    return comparison[comparison.flavor.isin(comparison.nutrient)].flavor.to_list()

# %%
#get_similar_foods("", consideration_of_elements=30)

# %%
similar_ing_list10 = pd.Series(flavor_per_entity_reduced.index).apply(get_similar_foods, consideration_of_elements=10)

# %%
similar_ing_list20 = pd.Series(flavor_per_entity_reduced.index).apply(get_similar_foods, consideration_of_elements=20)

# %%
similar_ing_list30 = pd.Series(flavor_per_entity_reduced.index).apply(get_similar_foods, consideration_of_elements=30)

# %%
similar_ing_list = pd.DataFrame()
similar_ing_list['list10'] = similar_ing_list10
similar_ing_list['list20'] = similar_ing_list20
similar_ing_list['list30'] = similar_ing_list30
similar_ing_list.set_index(flavor_per_entity_reduced.index, inplace=True)
# Out:
#                                                                         list10  \
# entity_alias_readable
# Abalone                                                                     []
# Abiyuch                                                        [Skunk currant]
# Acerola                                                                     []
# Acorn                                                                       []
# Adzuki bean                                                                 []
# Agar                                                                        []
# Agave                                                                       []
# Alaska blackfish                                                            []
# Alaska pollock                    [Pacific rockfish, Channel catfish, Buffalo]
# Alaska wild rhubarb                                                         []
# Albacore tuna                                                               []
# Alfalfa                                                                     []
# Allspice                                                          [Star Anise]
# Almond                                      [Hazelnut, Brazil Nut, Cashew nut]
# Alpinia                                                                     []
# Amaranth                                                        [Teff, Quinoa]
# American butterfish                                                         []
# American shad                                                               []
# Anchovy                                                                     []
# Anise                                [Star Anise, Cumin, Carom Seed, Tarragon]
# Annual wild rice                                                            []
# Apple                                                                   [Pear]
# Apple Brandy                 [Cherry Brandy, Brandy, Plum Brandy, Scotch Wh...
# Apple Cider Vinegar                                              [Apple Sauce]
# Apple Sauce                                                                 []
# Apricot                                                               [Loquat]
# Arabica coffee                                                              []
# Arrowhead                                                                   []
# Arrowroot                                                                   []
# Artichoke                                                                   []
# Asafoetida                                                                  []
# Ascidians                                                            [Tostada]
# Asparagus                                                             [Endive]
# Atlantic croaker                                                            []
# Atlantic halibut                                                       [Charr]
# Atlantic herring                                                            []
# Atlantic mackerel                                                  [Mule deer]
# Atlantic menhaden                                                   [Tilefish]
# Atlantic pollock                                                        [Cusk]
# Atlantic salmon                                                             []
# Atlantic wolffish                                                           []
# Avocado                                                                     []
# Babaco                                                                      []
# Babassu palm                                                                []
# Bagel                                                                       []
# Bakery Products                                                             []
# Bamboo shoots                               [Chanterelle, Jerusalem artichoke]
# Banana                                                                      []
# Barley                                                                      []
# Bartlett Pear                                                    [Apple Sauce]
# Basil                                                                       []
# Basmati Rice                                                                []
# Beans                                                                       []
# Bearded seal                                                                []
# Beaver                                                       [European rabbit]
# Beef                                                                        []
# Beef Processed                                         [Chicken, Pork, Mutton]
# Beefalo                                                                     []
# Beer                                                                        []
# Beetroot                                                           [Cucurbita]
# Beluga whale                                                                []
# Berry                                                                       []
# Bilberry                                                [Blueberry, Cranberry]
# Biscuit                                                                     []
# Bison                                                                   [Deer]
# Bitter Orange                                                               []
# Bittergourd                                  [Giant butterbur, Black-eyed pea]
# Black Tea                                                          [Green Tea]
# Black crowberry                                                             []
# Black huckleberry                                                           []
# Black salsify                                            [Jerusalem artichoke]
# Black-eyed pea                                                              []
# Blackberry                                                        [Loganberry]
# Blue Cheese                     [Romano Cheese, Feta Cheese, Roquefort Cheese]
# Blue whiting                                                                []
# Blueberry                                                                   []
# Bluefish                                                        [Dolphin fish]
# Bonito                                                          [Dolphin fish]
# Borage                                                  [Purslane, Corn salad]
# Boysenberry                                                                 []
# Brandy                         [Cherry Brandy, Apple Brandy, Plum Brandy, Gin]
# Brazil Nut                                                        [Cashew nut]
# Bread                                                                       []
# Breadfruit                                                      [Mountain yam]
# Breadnut tree seed                                                          []
# Broad whitefish                                                             []
# Broccoli                             [Cauliflower, Brussels Sprout, Cucurbita]
# Brown bear                                                                  []
# Brussels Sprout                                                  [Cauliflower]
# Buckwheat                                                               [Oats]
# Buffalo                                                                     []
# Bulgur                                                                      []
# Burbot                                                                      []
# Burdock                                                                     []
# Butter                                                                      []
# Buttermilk                                                             [Water]
# Butternut                                                                   []
# Butternut squash                                                            []
# Byrsonima crassifolia                                                       []
# Cabbage                                                                     []
# Camembert Cheese             [Limburger Cheese, Tilsit Cheese, Feta Cheese,...
# Canola Oil                                                                  []
# Capers                                                                      []
# Capsicum                                                                    []
# Caraway                                                                     []
# Cardamom                                                                    []
# Cardoon                                                         [Mountain yam]
# Caribou                                                                 [Deer]
# Carob                                                                       []
# Carom Seed                          [Cumin, Star Anise, Anise, Dill, Tarragon]
# Carrot                                                                      []
# Casein                                                                      []
# Cashew Apple                                                                []
# Cashew nut                                                        [Brazil Nut]
# Cassava                                                                     []
# Cassia                                               [Cinnamon, Summer savory]
# Catfish                                                                     []
# Catjang pea                                                                 []
# Cauliflower                                                        [Cucurbita]
# Caviar                                                                      []
# Celery                                                                      []
# Chamomile                                                                   []
# Champagne                         [Plum Wine, Rose Wine, Sparkling Wine, Wine]
# Channel catfish                                                      [Buffalo]
# Chanterelle                               [Bamboo shoots, Jerusalem artichoke]
# Chard                                                              [Dandelion]
# Charr                                                                       []
# Chayote                                                                     []
# Cheddar Cheese               [Provolone Cheese, Romano Cheese, Limburger Ch...
# Cheese                       [Munster Cheese, Tilsit Cheese, Limburger Chee...
# Cherimoya                                                                   []
# Cherry                                                                      []
# Cherry Brandy                         [Brandy, Apple Brandy, Plum Brandy, Gin]
# Cherry Pepper                                                               []
# Cherry tomato                                                               []
# Chervil                                                                 [Kale]
# Chestnut                                                                    []
# Chia                                                          [Teff, Amaranth]
# Chicken                                       [Beef Processed, Mutton, Turkey]
# Chickpea                                                             [Lentils]
# Chicory                                                    [Dandelion, Sorrel]
# Chinook salmon                                                              []
# Chive                                     [Garden cress, Watercress, Pak choy]
# Chocolate                                                                   []
# Chocolate mousse                                                            []
# Chocolate spread                                                            []
# Chum salmon                                                      [Pink salmon]
# Cider                                                                       []
# Cinnamon                                [Cassia, Summer savory, Winter savory]
# Cisco                                                                       []
# Citronella                                                                  []
# Citrus Peel Oil                                                [Bitter Orange]
# Clam                                                                        []
# Climbing bean                                                               []
# Cloud ear fungus                                                            []
# Cloudberry                                                                  []
# Clove                                     [Star Anise, Anise, Allspice, Cumin]
# Clupeinae                                                                   []
# Cocoa                                                                       []
# Cocoa butter                                                                []
# Cocoa powder                                                                []
# Coconut                                                                     []
# Codfish                                                                     []
# Coffee                                                                      []
# Coffee mocha                                                                []
# Cognac Brandy                                                               []
# Coho salmon                                                        [Swordfish]
# Colorado pinyon                                                             []
# Common Tuna                                                                 []
# Common carp                                                                 []
# Common ling                                                                 []
# Common octopus                                                              []
# Common persimmon                                                            []
# Common salsify                                                              []
# Comte Cheese                 [Munster Cheese, Tilsit Cheese, Romano Cheese,...
# Conch                                                                       []
# Condensed milk                                                              []
# Cooking oil                                                                 []
# Coriander                                                         [Carom Seed]
# Corn                                                             [Pomegranate]
# Corn Oil                                                                    []
# Corn chip                                              [Tortilla chip, Nachos]
# Corn grits                                                                  []
# Corn salad                                                                  []
# Cornbread                                                                   []
# Cottage Cheese                                                              []
# Crab                                                                        []
# Cranberry                                                                   []
# Crayfish                                                                    []
# Cream                                                              [Ice cream]
# Cream Cheese                                                     [Goat Cheese]
# Crispbread                                                                  []
# Cucumber                                                                    []
# Cucurbita                                    [Yellow zucchini, Green zucchini]
# Cumin                                          [Star Anise, Carom Seed, Anise]
# Currant                                                              [Truffle]
# Curry Leaf                                                                  []
# Cusk                                                                 [Snapper]
# Cuttlefish                                                                  []
# Dandelion                                                      [Chard, Sorrel]
# Dates                                                                    [Yam]
# Deer                                                                        []
# Deerberry                                                                   []
# Devilfish                                                                   []
# Dill                          [Carom Seed, Star Anise, Cumin, Anise, Allspice]
# Dock                                                              [Corn salad]
# Dolphin fish                                            [Yellowtail amberjack]
# Drumstick Leaf                                                              []
# Durian                                                                      []
# Egg                                                    [Squid, Trassi, Shrimp]
# Eggplant                          [Green zucchini, Yellow zucchini, Cucurbita]
# Elderberry                                                                  []
# Elk                                                                  [Buffalo]
# Emmental Cheese                  [Munster Cheese, Tilsit Cheese, Comte Cheese]
# Endive                                                                      []
# Enokitake                                                    [Oyster mushroom]
# Epazote                                                                     []
# European anchovy                                                            []
# European rabbit                                                             []
# Evaporated milk                                                             []
# Feijoa                                                                      []
# Fennel                                                                      []
# Fenugreek                                                          [Gram bean]
# Feta Cheese                  [Roquefort Cheese, Sheep Cheese, Tilsit Cheese...
# Fig                                                                         []
# Filbert                                                                     []
# Fireweed                                                                    []
# Fish                                                                [Fish Oil]
# Fish Oil                                                                    []
# Flatfish                                                                    []
# Flaxseed                                                                    []
# Florida pompano                                                             []
# Flour                                                                  [Fudge]
# Focaccia                                                                    []
# Frankfurter Sausage                                                         []
# French plantain                                                             []
# French toast                                                                []
# Freshwater drum                                                 [Striped bass]
# Freshwater eel                                                  [Striped bass]
# Fried Potato                                                                []
# Fruit preserve                                                              []
# Frybread                                                                    []
# Fudge                                                                       []
# Garcinia Indica                                                             []
# Garden cress                                                                []
# Garland chrysanthemum                                                       []
# Garlic                                                                      []
# Gelatin                                                             [Meringue]
# Gelatin dessert                                                             []
# Ghee                                                                        []
# Giant butterbur                                                             []
# Gin                                                                         []
# Ginger                                                                      []
# Ginkgo nuts                                                                 []
# Ginseng                                                                     []
# Goat Cheese                                   [Limburger Cheese, Cream Cheese]
# Goat Milk                                                       [Skimmed Milk]
# Gooseberry                                                                  []
# Gram bean                                                                   []
# Grape                                                           [Quince, Plum]
# Grapefruit                                                                  []
# Grapefruit Peel Oil                                                         []
# Great horned owl                                                            []
# Greater sturgeon                                                    [Bluefish]
# Green Beans                                         [Peas, Endive, Gooseberry]
# Green Tea                                                                   []
# Green turtle                                                            [Scup]
# Green zucchini                                    [Yellow zucchini, Cucurbita]
# Greenland halibut                                                           []
# Greylag goose                                                               []
# Groundcherry                                                                []
# Grouper                                        [Yellowtail amberjack, Snapper]
# Gruyere Cheese               [Limburger Cheese, Romano Cheese, Munster Chee...
# Guava                                                           [Passionfruit]
# Guinea hen                                                                  []
# Haddock                                                                     []
# Ham                                                                         []
# Hard wheat                                                                  []
# Hazelnut                                                           [Pistachio]
# Heart of palm                                                        [Tostada]
# Hibiscus tea                                                    [Coffee mocha]
# Honey                                                                       []
# Horchata                                                                    []
# Horned melon                                                          [Jicama]
# Horse                                                                       []
# Horseradish                                                           [Radish]
# Hot chocolate                                                               []
# Hyacinth                                                                    []
# Hyacinth bean                                                               []
# Ice cream                                                                   []
# Icing                                                                       []
# Irish moss                                                                  []
# Jackfruit                                                                   []
# Jalapeno                                                                    []
# Japanese chestnut                                                           []
# Japanese persimmon                                                          []
# Japanese pumpkin                                                            []
# Jasmine                                                       [Arabica coffee]
# Jellyfish                                                                   []
# Jerusalem artichoke                                              [Chanterelle]
# Jew's ear                                                                   []
# Jicama                                                                      []
# Jujube                                                                      []
# Junket                                                         [Tapioca pearl]
# Jute                                                                        []
# Kai lan                                                                     []
# Kale                                                                        []
# Kefir                                                                       []
# Kelp                                                                    [Agar]
# Kenaf                                                                       []
# Ketchup                                                      [Leavening agent]
# Kidney Beans                                                           [Beans]
# King mackerel                                                               []
# Kiwifruit                                                                   []
# Kohlrabi                                               [Rutabaga, Cauliflower]
# Komatsuna                                                               [Jute]
# Kombu                                                                       []
# Krill                                                                       []
# Kumquat                                                                     []
# Lake trout                                                                  []
# Lamb                                                              [Peanut Oil]
# Lambsquarters                                               [Butternut squash]
# Laurel                                                                      []
# Leather chiton                                                 [Albacore tuna]
# Leavening agent                                                      [Ketchup]
# Leek                                                                        []
# Lemon                                                                   [Lime]
# Lemon Balm                                                                  []
# Lemon Grass                                                                 []
# Lemon Peel Oil                [Grapefruit Peel Oil, Lime Peel Oil, Orange Oil]
# Lemon sole                                               [Pacific ocean perch]
# Lentils                                                             [Chickpea]
# Lettuce                                                                     []
# Lima Beans                                                                  []
# Limburger Cheese             [Tilsit Cheese, Munster Cheese, Romano Cheese,...
# Lime                                                                   [Lemon]
# Lime Peel Oil                                                               []
# Lingcod                                                              [Snapper]
# Lingonberry                                                                 []
# Liqourice                                                                   []
# Litchi                                                                      []
# Lobster                                                                     []
# Loganberry                                                                  []
# Longan                                                    [Natal plum, Jujube]
# Loquat                                                                      []
# Lotus                                                         [Water Chestnut]
# Lovage                                                                      []
# Lupine                                                                      []
# Macadamia Nut                                                               []
# Macaroni                                                                    []
# Mace                                                                        []
# Maitake                                                                     []
# Malabar spinach                                                         [Agar]
# Malay Apple                                                                 []
# Mallard duck                                                                []
# Malt                                                                   [Berry]
# Mandarin Orange                                                             []
# Mango                                                                       []
# Margarine                                                                   []
# Margarine like spread                                                       []
# Marjoram                         [Oregano, Winter savory, Sage, Summer savory]
# Marshmallow                                                                 []
# Mate                                                                        []
# Meat                                                                        []
# Meatball                                                                    []
# Melon                                                     [Musk Melon, Loquat]
# Meringue                                                                    []
# Mexican groundcherry                                                        []
# Mexican oregano                                                             []
# Milk                                                                        []
# Milk Fat                                                                    []
# Milk Human                                                                  []
# Milk Powder                                                                 []
# Milkfish                                                                    []
# Milkshake                                                                   []
# Millet                                                                 [Pasta]
# Mint                                                  [Spearmint, Bittergourd]
# Miso                                                                    [Salt]
# Molasses                                                                    []
# Mollusc                                                              [Haddock]
# Monkfish                                                             [Snapper]
# Moose                                                               [Squirrel]
# Moth bean                                                                   []
# Mountain yam                                                                []
# Mozzarella Cheese            [Munster Cheese, Tilsit Cheese, Limburger Chee...
# Mulberry                                                     [Muscadine grape]
# Mule deer                                                                   []
# Multigrain bread                                                            []
# Mung bean                                                                   []
# Munster Cheese               [Tilsit Cheese, Limburger Cheese, Romano Chees...
# Muscadine grape                                                             []
# Mushroom                                                                    []
# Musk Melon                                                                  []
# Muskrat                                                                     []
# Mustard                                                               [Wasabi]
# Mustard Oil                                                                 []
# Mutton                                                                [Turkey]
# Myrtle                                                               [Caraway]
# Nachos                                                             [Corn chip]
# Nance                                                                       []
# Naranjilla                                                                  []
# Narrowleaf cattail                                       [Alaska wild rhubarb]
# Natal plum                                                                  []
# New Zealand spinach                                                         []
# Nigella Seed                                                                []
# Nopal                                                    [Alaska wild rhubarb]
# North Pacific giant octopus                                                 []
# Northern bluefin tuna                                                       []
# Northern pike                                                               []
# Norway pout                                                                 []
# Nutmeg                                                                      []
# Nuts                                                                        []
# Nuttall cockle                                                              []
# Oat bread                                                                   []
# Oats                                                               [Buckwheat]
# Ocean pout                                                           [Snapper]
# Oil palm                                                                    []
# Okra                                                                        []
# Olive                                                                       []
# Onion                                                                       []
# Opossum                                                              [Raccoon]
# Orange                                                [Mandarin Orange, Lemon]
# Orange Oil                   [Grapefruit Peel Oil, Lemon Peel Oil, Lime Pee...
# Orange roughy                                                               []
# Oregano                         [Marjoram, Sage, Winter savory, Summer savory]
# Oregon yampah                                                               []
# Ostrich                                                              [Caribou]
# Ostrich fern                                                      [Corn salad]
# Oyster                                                                      []
# Oyster mushroom                                                    [Enokitake]
# Pacific herring                                                [American shad]
# Pacific jack mackerel                                                       []
# Pacific ocean perch                                               [Lemon sole]
# Pacific rockfish                                                            []
# Pacific sardine                                                             []
# Pak choy                                                                    []
# Paneer                                                                 [Prawn]
# Papaya                                                                      []
# Parmesan Cheese              [Romano Cheese, Provolone Cheese, Limburger Ch...
# Parsley                                                                     []
# Parsnip                                                                     []
# Passionfruit                                                          [Banana]
# Pasta                                                                 [Millet]
# Pate                                                                        []
# Peach                                                       [Plum, Gooseberry]
# Peanut                                                                [Almond]
# Peanut Butter                                                               []
# Peanut Oil                                                       [Mustard Oil]
# Pear                                                                        []
# Peas                                                             [Green Beans]
# Pecans                                                 [Macadamia Nut, Walnut]
# Pectin                                                 [Tapioca pearl, Junket]
# Pepino                                                                      []
# Pepper                                           [Star Anise, Cumin, Allspice]
# Peppermint                                      [Mint, Spearmint, Bittergourd]
# Persimmon                                                                   []
# Pheasant                                                                    []
# Phyllo dough                                                    [Raisin bread]
# Pie crust                                                          [Corn chip]
# Pigeon Pea                                                                  []
# Piki bread                                                                  []
# Pili nut                                                                    []
# Pine                                                              [Cashew nut]
# Pineapple                                                              [Apple]
# Pink salmon                                      [Chum salmon, Sockeye salmon]
# Pistachio                                                           [Hazelnut]
# Pita bread                                                      [Raisin bread]
# Pitanga                                                                     []
# Plum                                                                   [Peach]
# Plum Brandy                  [Cherry Brandy, Brandy, Apple Brandy, Scotch W...
# Plum Wine                    [Champagne, Rose Wine, Sparkling Wine, Wine, R...
# Pollock                                                                     []
# Pomegranate                                                                 []
# Popcorn                                                                     []
# Poppy Seed                                                                  []
# Pork                                                                    [Beef]
# Port Wine                    [Plum Wine, Champagne, Rose Wine, Sparkling Wi...
# Potato                                                                      []
# Potato bread                                                                []
# Potato chip                                                                 []
# Prairie turnip                                                              []
# Prawn                                                                       []
# Prickly Pear                                                                []
# Provolone Cheese             [Romano Cheese, Munster Cheese, Tilsit Cheese,...
# Pummelo                                                                     []
# Pumpkin                                                                     []
# Pumpkinseed sunfish                                                         []
# Purple laver                                                                []
# Purple mangosteen                                                   [Rambutan]
# Purslane                                                              [Borage]
# Quail                                                                       []
# Quince                                                                      []
# Quinoa                                                              [Amaranth]
# Rabbit                                                                      []
# Raccoon                                                              [Opossum]
# Radish                                                                [Turnip]
# Rainbow smelt                                                      [Sea trout]
# Rainbow trout                                                               []
# Raisin                                                                      []
# Raisin bread                                                      [Rice bread]
# Rambutan                                                                    []
# Rapini                                                                      []
# Raspberry                                                         [Loganberry]
# Red Currant                                                                 []
# Red Wine                     [Champagne, Sparkling Wine, Plum Wine, Wine, C...
# Red king crab                                                               []
# Red rice                                                                    []
# Rhubarb                           [Cucurbita, Yellow zucchini, Green zucchini]
# Rice                                                                        []
# Rice bread                                                      [Raisin bread]
# Rice cake                                                                   []
# Ricotta Cheese                                                              []
# Ringed seal                                                                 []
# Rocket salad                                                                []
# Roe                                                                         []
# Romano Cheese                [Sheep Cheese, Munster Cheese, Tilsit Cheese, ...
# Roquefort Cheese             [Sheep Cheese, Feta Cheese, Limburger Cheese, ...
# Rose                                                                        []
# Rose Wine                         [Champagne, Plum Wine, Sparkling Wine, Wine]
# Rose hip                                                                    []
# Roseapple                                                                   []
# Roselle                                                                     []
# Rosemary                                                               [Thyme]
# Rowal                                                                       []
# Rum                                                    [Scotch Whisky, Whisky]
# Rutabaga                                                                    []
# Rye                                                                         []
# Rye Bread                                                                   []
# Sablefish                                                           [Bluefish]
# Safflower                                                                   []
# Saffron                                                             [Turmeric]
# Sage                                        [Winter savory, Marjoram, Oregano]
# Sago palm                                                                   []
# Sake                                                                [Horchata]
# Salmon                                                                      []
# Salmonberry                                                                 []
# Salt                                                                        []
# Sapodilla                                                                   []
# Saskatoon berry                                                             []
# Sauce                                                                [Ketchup]
# Scallop                                                           [Clam, Crab]
# Scotch Whisky                                                    [Whisky, Rum]
# Scup                                                                        []
# Sea cucumber                                                  [Nuttall cockle]
# Sea trout                                                                   []
# Semolina                                                                    []
# Sesame                                                                      []
# Sesbania flower                                          [Agar, Yardlong bean]
# Shallot                                                                     []
# Shark                                                                       []
# Sheefish                                                                    []
# Sheep Cheese                 [Tilsit Cheese, Roquefort Cheese, Limburger Ch...
# Sheep Milk                                           [Goat Milk, Skimmed Milk]
# Sheepshead                                                                  []
# Shiitake                                                           [Enokitake]
# Shortening                                                                  []
# Shrimp                                                       [Squid, Crayfish]
# Skimmed Milk                                                                []
# Skunk currant                                                               []
# Smelt                                                                       []
# Smoked Fish                                                                 []
# Snail                                                                       []
# Snapper                                                                     []
# Sockeye salmon                                                   [Pink salmon]
# Sorghum                                                                [Spelt]
# Sorrel                                                                  [Kale]
# Sour Cherry                                                                 []
# Sourdock                                                                    []
# Sourdough                                                                   []
# Soursop                                                 [Mexican groundcherry]
# Soy cream                                                                   []
# Soy milk                                                                    []
# Soy yogurt                                                                  []
# Soybean                                                                     []
# Soybean Oil                                                      [Mustard Oil]
# Spanish mackerel                                                     [Snapper]
# Sparkling Wine                         [Plum Wine, Champagne, Rose Wine, Wine]
# Spearmint                                                     [Mint, Rosemary]
# Spelt                                                                [Sorghum]
# Spinach                                                            [Dandelion]
# Spiny lobster                                                          [Shark]
# Spirulina                                                                   []
# Spot croaker                                                       [Sea trout]
# ...
# Prairie turnip                                                              []
# Prawn                                                                       []
# Prickly Pear                                                                []
# Provolone Cheese             [Goat Cheese, Romano Cheese, Sheep Cheese, Mun...
# Pummelo                                                 [Mexican groundcherry]
# Pumpkin                                                             [Pak choy]
# Pumpkinseed sunfish          [Scup, Sea trout, Snapper, White sucker, Atlan...
# Purple laver                                                                []
# Purple mangosteen                                                   [Rambutan]
# Purslane                     [Welsh onion, Borage, New Zealand spinach, Jut...
# Quail                                        [Striped bass, Atlantic mackerel]
# Quince                             [Cherry, Gooseberry, Naranjilla, Sapodilla]
# Quinoa                                       [Teff, Amaranth, Spelt, Pili nut]
# Rabbit                                                      [Horse, Clupeinae]
# Raccoon                      [European rabbit, Opossum, Dolphin fish, Beefalo]
# Radish                                                                [Turnip]
# Rainbow smelt                [Sea trout, Striped bass, Pumpkinseed sunfish,...
# Rainbow trout                            [Clupeinae, Horse, Greenland halibut]
# Raisin                                                     [Truffle, Hyacinth]
# Raisin bread                               [Pacific jack mackerel, Rice bread]
# Rambutan                                                                    []
# Rapini                                                       [Kale, Moth bean]
# Raspberry                         [Gooseberry, Loganberry, Blackberry, Feijoa]
# Red Currant                  [Pomegranate, Cucurbita, Gooseberry, Yellow zu...
# Red Wine                     [Rose Wine, Champagne, Sparkling Wine, Plum Wi...
# Red king crab                                               [European anchovy]
# Red rice                                                    [Annual wild rice]
# Rhubarb                           [Cucurbita, Yellow zucchini, Green zucchini]
# Rice                                                                        []
# Rice bread                               [Pacific jack mackerel, Raisin bread]
# Rice cake                                                                   []
# Ricotta Cheese                [Curry Leaf, Milk Fat, Sheep Milk, Skimmed Milk]
# Ringed seal                      [Nuttall cockle, Sea cucumber, Spiny lobster]
# Rocket salad                                                     [Jute, Nopal]
# Roe                                                 [Sea trout, American shad]
# Romano Cheese                [Sheep Cheese, Munster Cheese, Roquefort Chees...
# Roquefort Cheese             [Sheep Cheese, Tilsit Cheese, Feta Cheese, Lim...
# Rose                                             [Apple Sauce, Nuttall cockle]
# Rose Wine                    [Champagne, Plum Wine, Sparkling Wine, Red Win...
# Rose hip                                                                    []
# Roseapple                                                    [Black crowberry]
# Roselle                                                [Nopal, Prairie turnip]
# Rosemary                     [Cumin, Star Anise, Thyme, Pepper, Spearmint, ...
# Rowal                                                        [Black crowberry]
# Rum                          [Scotch Whisky, Whisky, Port Wine, Sparkling W...
# Rutabaga                                            [Radish, Japanese pumpkin]
# Rye                                                                         []
# Rye Bread                                         [Semolina, Chocolate spread]
# Sablefish                    [American shad, White sucker, Bluefish, Dolphi...
# Safflower                                             [Amaranth, Quinoa, Teff]
# Saffron                           [Turmeric, Cumin, Anise, Cardamom, Tarragon]
# Sage                         [Winter savory, Summer savory, Marjoram, Orega...
# Sago palm                                          [Great horned owl, Ginseng]
# Sake                                                         [Horchata, Vodka]
# Salmon                                      [Steller sea lion, Striped mullet]
# Salmonberry                                                                 []
# Salt                                                                    [Miso]
# Sapodilla                                                                   []
# Saskatoon berry                                              [Black crowberry]
# Sauce                                         [Leavening agent, Ketchup, Salt]
# Scallop                                [Clam, Crab, Mollusc, Multigrain bread]
# Scotch Whisky                [Whisky, Rum, Sparkling Wine, Rose Wine, Port ...
# Scup                         [Sea trout, Striped bass, Pumpkinseed sunfish,...
# Sea cucumber                                                  [Nuttall cockle]
# Sea trout                                    [Atlantic pollock, Rainbow smelt]
# Semolina                                                      [Fruit preserve]
# Sesame                                                            [Poppy Seed]
# Sesbania flower                             [Agar, Yardlong bean, Boysenberry]
# Shallot                          [Mountain yam, Common salsify, Winter squash]
# Shark                          [Scup, Guinea hen, Striped bass, Rainbow smelt]
# Sheefish                                                        [Beluga whale]
# Sheep Cheese                 [Munster Cheese, Tilsit Cheese, Roquefort Chee...
# Sheep Milk                   [Goat Milk, Skimmed Milk, Nuttall cockle, Sea ...
# Sheepshead                   [Sea trout, American shad, Snapper, Atlantic p...
# Shiitake                                                  [Maitake, Enokitake]
# Shortening                                [Fudge, Flour, Topping, Cooking oil]
# Shrimp                                               [Squid, Crayfish, Trassi]
# Skimmed Milk                 [Sheep Milk, Sea cucumber, Malay Apple, Goat M...
# Skunk currant                     [Muscadine grape, Abiyuch, Mulberry, Jujube]
# Smelt                             [Buffalo, Channel catfish, Alaska blackfish]
# Smoked Fish                                                  [Prawn, Frybread]
# Snail                                               [Horse, Greenland halibut]
# Snapper                      [White sucker, Dolphin fish, Tilefish, Spanish...
# Sockeye salmon               [Pink salmon, Chum salmon, Deer, Ostrich, Biso...
# Sorghum                      [Quinoa, Spelt, Amaranth, Teff, Yellow pond li...
# Sorrel                                  [Kale, Chervil, Kai lan, Garden cress]
# Sour Cherry                                                      [Salmonberry]
# Sourdock                          [Corn salad, Devilfish, New Zealand spinach]
# Sourdough                                                                   []
# Soursop                                         [Mexican groundcherry, Jujube]
# Soy cream                    [Apple Sauce, Byrsonima crassifolia, Nuttall c...
# Soy milk                                             [Milk Human, Water, Whey]
# Soy yogurt                                                                  []
# Soybean                                   [Beans, Lima Beans, Peanut, Avocado]
# Soybean Oil                                            [Mustard Oil, Macaroni]
# Spanish mackerel                             [Snapper, Dolphin fish, Tilefish]
# Sparkling Wine               [Plum Wine, Champagne, Rose Wine, Red Wine, Wi...
# Spearmint                                  [Mint, Rosemary, Peppermint, Thyme]
# Spelt                        [Quinoa, Teff, Sorghum, Amaranth, Yellow pond ...
# Spinach                                       [Chard, Dandelion, Kale, Sorrel]
# Spiny lobster                 [Shark, Guinea hen, Striped bass, Rainbow smelt]
# Spirulina                                         [Catjang pea, Hyacinth bean]
# Spot croaker                                     [Sea trout, Atlantic pollock]
# Spread                                                                [Junket]
# Squab                                                    [Clupeinae, Semolina]
# Squid                        [Atlantic croaker, Guinea hen, Mule deer, Fres...
# Squirrel                     [Moose, European rabbit, Rainbow smelt, Spot c...
# Star Anise                   [Cumin, Anise, Carom Seed, Turmeric, Tarragon,...
# Starfruit                                [Gooseberry, Plum, Peach, Blackberry]
# Steller sea lion                        [Atlantic menhaden, Beefalo, Tilefish]
# Strawberry                   [Pineapple, Plum, Gooseberry, Peach, Mango, Ra...
# Strawberry Jam                                                              []
# Striped bass                 [Freshwater eel, Freshwater drum, Atlantic cro...
# Striped mullet               [Snapper, Sea trout, Atlantic pollock, Atlanti...
# Stuffing                                   [Pie crust, Focaccia, French toast]
# Sturgeon                                [Blue whiting, Northern pike, Whiting]
# Sugar                                   [Greylag goose, Syrup, Fruit preserve]
# Sugar substitute                                                            []
# Summer savory                [Winter savory, Cumin, Sage, Star Anise, Carom...
# Sweet Potato                                                        [Pak choy]
# Sweet custard                                            [Milkshake, Horchata]
# Sweetcorn                                                                   []
# Swiss Cheese                                              [Rum, Scotch Whisky]
# Swordfish                    [Pacific rockfish, Yellowfin tuna, Coho salmon...
# Syrup                                                         [Fruit preserve]
# Tamarind                                    [Lemon Grass, Cardamom, Fenugreek]
# Tangerine                                                [Malay Apple, Babaco]
# Tapioca pearl                                                 [Pectin, Junket]
# Taro                                                    [Yautia, Mountain yam]
# Tarragon                     [Turmeric, Anise, Carom Seed, Saffron, Star An...
# Tartary buckwheat                                                 [Irish moss]
# Tea                                               [Bilberry, Cranberry, Apple]
# Teff                         [Quinoa, Spelt, Sorghum, Chia, Amaranth, Pili ...
# Thyme                        [Oregano, Marjoram, Summer savory, Winter savo...
# Tilefish                     [Snapper, Dolphin fish, White sucker, Spanish ...
# Tilsit Cheese                [Munster Cheese, Sheep Cheese, Limburger Chees...
# Tinda                                                                 [Jicama]
# Tofu                                                          [Soy milk, Whey]
# Tomato                       [Gooseberry, Green Beans, Fig, Peach, Apricot,...
# Topping                                                                     []
# Tortilla                                                                    []
# Tortilla chip                [Corn chip, Nachos, Cooking oil, Pie crust, Ic...
# Tostada                                             [Heart of palm, Jellyfish]
# Trassi                                               [Squid, Alaska blackfish]
# Tree fern                                                                   []
# Triticale                                                           [Pili nut]
# True frog                                    [Northern pike, Whiting, Catfish]
# True seal                                                                   []
# Truffle                                                             [Hyacinth]
# Turbot                                                             [True frog]
# Turkey                                    [Pheasant, Catfish, Turbot, Whiting]
# Turmeric                     [Saffron, Cumin, Anise, Star Anise, Tarragon, ...
# Turnip                                                                      []
# Ucuhuba                                                                     []
# Vanilla                                                          [Lingonberry]
# Vermouth                                                                    []
# Vinegar                                                    [Water, Milk Human]
# Vodka                                          [Fruit preserve, Greylag goose]
# Wakame                                                                      []
# Walleye                      [Sea trout, Snapper, White sucker, Atlantic po...
# Walnut                       [Brazil Nut, Cashew nut, Hazelnut, Macadamia N...
# Walrus                                                         [Albacore tuna]
# Wasabi                                                                      []
# Water                                                             [Milk Human]
# Water Chestnut                         [Arrowhead, Mountain yam, Taro, Yautia]
# Watercress                   [Pak choy, Garden cress, Kale, Sorrel, Chard, ...
# Welsh onion                                   [New Zealand spinach, Butternut]
# Wheat                                           [Cashew nut, Brazil Nut, Pine]
# Wheaten Bread                                             [Ringed seal, Krill]
# Whelk                                                                       []
# Whey                                                                   [Water]
# Whisky                       [Scotch Whisky, Rum, Port Wine, Rose Wine, Plu...
# White Bread                                                        [True seal]
# White Currant                                                               []
# White Wine                                                              [Beer]
# White lupine                                                 [Agar, Moth bean]
# White sucker                 [Sea trout, Snapper, Dolphin fish, Pumpkinseed...
# Whitefish                             [Pheasant, Atlantic wolffish, Clupeinae]
# Whiting                                    [Catfish, True frog, Northern pike]
# Wholewheat Bread                                             [Leavening agent]
# Wild boar                                                         [Brown bear]
# Wild rice                                                           [Pili nut]
# Wine                         [Champagne, Plum Wine, Rose Wine, Sparkling Wi...
# Winged bean                                                    [Hyacinth bean]
# Winter savory                [Summer savory, Sage, Marjoram, Cumin, Oregano...
# Winter squash                [Mountain yam, Common salsify, Mexican groundc...
# Wonton wrapper                             [Pacific jack mackerel, Rice bread]
# Woodapple                                                             [Pepino]
# Wort                                             [Peanut Butter, Cashew Apple]
# Yam                                               [Bamboo shoots, Chanterelle]
# Yardlong bean                             [Agar, Sesbania flower, Boysenberry]
# Yautia                                                    [Taro, Mountain yam]
# Yellow pond lily                                              [Spelt, Sorghum]
# Yellow zucchini                                    [Green zucchini, Cucurbita]
# Yellowfin tuna               [Pacific rockfish, Swordfish, Coho salmon, Soc...
# Yellowtail amberjack         [Snapper, Dolphin fish, Tilefish, Spanish mack...
# Yogurt                                              [Milk Fat, Soy milk, Tofu]

# %%
similar_ing_list.to_pickle('../data_discovery/similar_food_ingredients.pkl')

# %%
#similar_ing_list

# %%
#flavor_per_entity_reduced.sample(10).index

# %%
#for base in (molecules_per_entity, flavor_per_entity_reduced):
#    word = 'True frog'
#    total_similitude = {
#        'flavor': get_top_similarities(
#            word, 
#            similarity_metric='cosine', 
#            base_df=base
#
#        ).rename(columns={'entity':'flavor'}),
#        'nutrients': get_top_similarities(
#            word, 
#            similarity_metric='cosine',
#            base_df=nutrients_per_entity_reduced
#            #base_df=nutrients_per_entity_reduced
#        ).rename(columns={'entity':'nutrient'}),
#    }

#    comparison = pd.concat([total_similitude['flavor'], total_similitude['nutrients']], axis=1).head(50)
#    print(comparison[comparison.flavor.isin(comparison.nutrient)].flavor.to_list())

# %%
#total_similitude['nutrients']

# %%
#flavor_molecules_list = graph_flavor_molecules_df_vector.columns.drop('entity_alias_readable')

# %% [markdown]
# # How to include a new food-ingredient?
# - 1) Search the molecules of the corresponding food, make an intersection of those molecules with the corresponding flavor molecules in the flavor molecules list. Then just take the intersection as a list of molecules.
#     - 1.1) For example: `new_ingredient: [flavor_molecule1, flavor_molecule2, ... flavor_moleculeN]`
#     - 1.2) The best case scenario is that this ingredient can be found in [foodb](https://foodb.ca/), since it contains the molecules information of an ingredient, and only a rapid search must be done within the compounds and molecules that are founded there and the flavor_molecules_list that are found in flavordb.
# - 2) Get the nutritional information for the food, thinking on 100g of the ingredient.
#     - 2.1) The nutrients must be the same format as the one found in the [edamam's website](https://developer.edamam.com/food-database-api-docs) (in the Nutrient Guide section).
#     - 2.2) The best case scenario is that this ingredient can be found in [edammams api](https://developer.edamam.com/food-database-api-demo).
