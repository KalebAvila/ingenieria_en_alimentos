# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_colwidth', 1000)

# %%
# Read data
branded_data = pd.read_csv('../data/raw/FoodData_Central_csv_2023-04-20/branded_food.csv')
#nutrient_data = pd.read_csv('../data/raw/FoodData_Central_csv_2023-04-20/food_nutrient.csv')
# Out:
# /tmp/ipykernel_1561/1195110988.py:2: DtypeWarning: Columns (2,3,4,6,9,12,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   branded_data = pd.read_csv('../data/raw/FoodData_Central_csv_2023-04-20/branded_food.csv')

# %%
categories = branded_data.branded_food_category.value_counts().reset_index()
categs = categories[categories.branded_food_category.apply(lambda x: len(x)) < 100]
#categs.to_csv('../data_discovery/branded_food_categories.csv')

# %%
columns = ['fdc_id', 'brand_owner', 'ingredients', 'branded_food_category']
bd = branded_data[branded_data.branded_food_category.isin(categs.branded_food_category)][columns]
bd.to_csv('../data_discovery/all_branded_foods_usda.csv')

# %%
bd
# Out:
#           fdc_id                               brand_owner  \
# 0        1105904  Richardson Oilseed Products (US) Limited
# 1        1105905                     CAMPBELL SOUP COMPANY
# 2        1105906                     CAMPBELL SOUP COMPANY
# 3        1105907                     CAMPBELL SOUP COMPANY
# 4        1105908                     CAMPBELL SOUP COMPANY
# ...          ...                                       ...
# 1845292  2554910                  Mt. Garfield Winery Corp
# 1845293  2554911                           All Market Inc.
# 1845294  2554912                        Chaneys Dairy Barn
# 1845295  2554913               Ittella International, Inc.
# 1845296  2554914                     Kingdom Animalia, LLC
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ingredients  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Vegetable Oil
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 INGREDIENTS: BEEF STOCK, CONTAINS LESS THAN 2% OF: MIREPOIX (CARROTS, CELERY, ONIONS), SALT, NATURAL FLAVORING, YEAST EXTRACT, CANE SUGAR.
# 2                                                                                                                                                                                                                                                                                                                                                                                     INGREDIENTS: CLAM STOCK, POTATOES, CLAMS, CREAM, VEGETABLE OIL (CORN, CANOLA, AND/OR SOYBEAN), CELERY, CONTAINS LESS THAN 2% OF: MODIFIED FOOD STARCH, SALT, WHEAT FLOUR, SOY PROTEIN CONCENTRATE, UNCURED SMOKED BACON PIECES-NO NITRATES OR NITRITES ADDED, EXCEPT FOR THOSE NATURALLY OCCURRING IN SEA SALT (PORK, WATER, SEA SALT, SUGAR), DRIED ONIONS, SPICES, SODIUM PHOSPHATE, FLAVORING, CLAM EXTRACT, SUCCINIC ACID, SUGAR, SOY LECITHIN, SOY SAUCE (SOYBEANS, WHEAT, SALT).CONTAINS: COD, WHEAT, MILK, SOY.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                           INGREDIENTS: WATER, CREAM, BROCCOLI, CELERY, VEGETABLE OIL (CORN, CANOLA, AND/OR SOYBEAN), MODIFIED FOOD STARCH, CHEDDAR CHEESE** (CHEDDAR CHEESE [CULTURED MILK, SALT, ENZYMES], WHEY, SALT, SODIUM PHOSPHATE), CONTAINS LESS THAN 2% OF: BUTTER, PARMESAN AND CHEDDAR CHEESE (MILK, CULTURES, SALT, ENZYMES), WHEAT FLOUR, SALT, POTATOES**, ONIONS**, SOY PROTEIN CONCENTRATE, ROASTED GARLIC**, ANNATTO EXTRACT FOR COLOR, SOY LECITHIN.  **DRIEDCONTAINS: WHEAT, MILK, SOY.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              INGREDIENTS: CHICKEN STOCK, CONTAINS LESS THAN 2% OF: YEAST EXTRACT, DEHYDRATED CHICKEN, NATURAL FLAVORING, CARROT JUICE CONCENTRATE, CELERIAC JUICE CONCENTRATE, CHICKEN FAT, ONION EXTRACT.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 1845292  ARCADIAN HARVEST LETTUCE (BLEND OF LEAF LETTUCES), RANCH DRESSING (BUTTERMILK [CULTURED PASTEURIZED PART-SKIM MILK, NONFAT MILK POWDER, SALT], SOYBEAN OIL AND/OR CANOLA OIL, WATER, EGG YOLK, NATURAL FLAVORS, CONTAINS LESS THAN 2% OF: DEHYDRATED GARLIC, DEHYDRATED ONION, DEHYDRATED PARSLEY, DISTILLED VINEGAR, GLUCONO DELTA LACTONE, PROPYLENE GLYCOL ALGINATE, SALT, SODIUM CITRATE, SPICES [CONTAINS MUSTARD], SUGAR, TITANIUM DIOXIDE [COLOR], XANTHAN GUM), TOMATOES, RED CABBAGE, HAM WITH WATER AND SMOKE FLAVOR ADDED (PORK [CURED WITH: WATER, DEXTROSE, SALT, SODIUM PHOSPHATE, SODIUM ERYTHORBATE, NATURAL SMOKE FLAVOR, SODIUM NITRITE]), WHITE TURKEY (WHITE TURKEY, WATER, MODIFIED FOOD STARCH, SALT, DEXTROSE, SODIUM PHOSPHATE), CHEDDAR CHEESE (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES, ANNATTO, VEGETABLE COLOR [IF COLORED], CORN STARCH [ANTI-CAKING AGENT]).
# 1845293                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                COCONUT WATER FROM CONCENTRATE (WATER, COCONUT WATER CONCENTRATE), SUGAR, NATURAL PINEAPPLE FLAVOR WITH OTHER NATURAL FLAVORS, COCONUT PUREE, VITAMIN C (ASCORBIC ACID), GELLAN GUM*.
# 1845294                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               WHOLE MILK, VITAMIN D3
# 1845295                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            CAULIFLOWER, CORN FLOUR, GRANA PADANO CHEESE (MILK, SALT, RENNET, LYSOZYME PROTEIN [EGG] AS PRESERVATIVE), DEHYDRATED POTATO, WATER, SUNFLOWER OIL, TAPIOCA STARCH, SALT, CHIVES, SPICES.
# 1845296                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           MARCONA ALMONDS (ORIGIN: SPAIN), TRUFFLE SALT (SEA SALT, TRUFFE, WHITE TRUFFLE ESSENCE), OLIVE OIL (WHITE TRUFFLE ESSENCE), SUNFLOWER OIL.
#
#                             branded_food_category
# 0                                     Oils Edible
# 1                           Herbs/Spices/Extracts
# 2                                  Prepared Soups
# 3                                  Prepared Soups
# 4                           Herbs/Spices/Extracts
# ...                                           ...
# 1845292       Pickles, Olives, Peppers & Relishes
# 1845293                         Plant Based Water
# 1845294                                      Milk
# 1845295                Frozen Patties and Burgers
# 1845296  Popcorn, Peanuts, Seeds & Related Snacks
#
# [1834524 rows x 4 columns]

# %%
interesting_categories = [
    'Cheese',
    'Cheese/Cheese Substitutes',
    'Chocolate',
    'Yogurt',
    'Yogurt/Yogurt Substitutes'
    'Soda',
    'Water',
    'Vegetable & Cooking Oils',
    'Milk',
    'Plant Based Milk',
    'Milk/Milk Substitutes',
    'Meat Substitutes',
]
branded_data.branded_food_category.value_counts().iloc[90:130]
branded_data[branded_data.branded_food_category.fillna('').str.lower().str.contains('substitute')].branded_food_category.value_counts()
# Out:
# branded_food_category
# Eggs & Egg Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             3520
# Yogurt/Yogurt Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          2522
# Coffee/Tea/Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              380
# Cheese/Cheese Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           350
# Butter/Butter Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           118
# Sugars/Sugar Substitute Products                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     42
# Eggs/Eggs Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                21
# Milk/Milk Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                19
# Meat Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     11
# Yogurt/Yogurt Substitutes (Perishable)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                7
# Cream/Cream Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               6
# Sugar Candy/Sugar Candy Substitutes Confectionery                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     3
# Eggs Products/Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Includes any products that can be described/observed as frozen food made from the curd of milk, separated from the whey, sometimes fermented, and usually pressed, cooked, smoked, matured, or heated and mixed with artificial ingredients, such as emulsifiers, colourings and flavourings. These products must be frozen to extend their consumable life. These products include natural, processed cheese, cheese with added ingredients, such as herbs and nuts, in blocks, rolls, slices, grated, cubes, spreadable and portions. Excludes products such as Shelf Stable and Perishable Cheeses, all Cheese Substitutes and Cheese-Based/Flavoured Meals.       1
# Name: count, dtype: int64

# %%
deserving_columns = ['fdc_id', 'brand_owner', 'ingredients', 'branded_food_category']
plant_based_milk = branded_data[branded_data.branded_food_category=='Milk/Milk Substitutes'][deserving_columns]
plant_based_milk['ingredients'] = plant_based_milk.ingredients.str.lower().str.strip().str.replace('organic', '')

# %%
milk_sample = branded_data[branded_data.branded_food_category=='Milk/Milk Substitutes']
sample = milk_sample[deserving_columns].sample(10)
sample['ingredients'] = sample.ingredients.str.lower().str.strip().str.replace('organic', '').str.replace('ingredients:', '').str.replace(' and ', ',').str.replace('natural', '').replace('artificial', '')
sample
# Out:
#           fdc_id                          brand_owner  \
# 291510    605944                       Conagra Brands
# 294654    612232  The Coca-Cola Company-0049000000016
# 572082   1163704                   Conagra Brands Inc
# 291512    605948                       Conagra Brands
# 1807282  2516900                The Coca-Cola Company
# 856239   1455551                   Conagra Brands Inc
# 369253    769892                                  NaN
# 370041    771468  The Coca-Cola Company-0049000000016
# 368874    769134  The Coca-Cola Company-0049000000016
# 1807326  2516944                   Conagra Brands Inc
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ingredients  \
# 291510                                                          water, cheddar cheese (cheese [cultured pasteurized milk, salt, enzymes], water, salt, potassium sorbate), soybean oil, modified corn starch, contains 2% or less of: chili peppers, jalapeno peppers, cheese blend (cheddar, granular, semi-soft,,blue cheese [pasteurized milk, cheese cultures, salt, enzymes], water, salt, lactic acid, vinegar, citric acid,  flavor), tomato paste, salt, disodium phosphate, fd&c yellow 5 & 6, datem,citric acid. contains: milk.
# 294654                                                                                                                                                                                                                                                                                                                                            almondmilk (water,almonds), cane sugar, pea protein, less than 1% of: dutch cocoa (processed with alkali),  flavors, calcium phosphate, sea salt, pectin, gellan gum,sunflower lecithin.
# 572082                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             instant nonfat dry milk, vitamins a,d3.
# 291512   water, soybean oil, cheddar cheese (cheese [cultured pasteurized milk, salt, enzymes], water, salt, potassium sorbate), modified corn starch, maltodextrin, nonfat dry milk, butter (cream, salt), less than 2% of: corn starch, cheese blend (cheddar, granular, semisoft,,blue cheese [pasteurized milk, cheese cultures, salt, enzymes], water, salt, lactic acid, vinegar, citric acid,  flavor), salt, sodium phosphate, distilled vinegar, datem, lactic acid, autolyzed yeast extract, yellow 6, yellow 5. contains: milk.
# 1807282                                                                                                                                                                                                                                                                                                                                     filtered water, almondmilk (water,almonds), cane sugar, pea protein, less than 1% of:  flavors, calcium phosphate, vanilla extract, sea salt, pectin, gellan gum, sunglower lecithin,cinnamon.
# 856239                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             instant nonfat dry milk, vitamins a,d3.
# 369253                                                                                                                                                                                                                                                       sugar, whole milk powder, cocoa butter, cocoa mass, desiccated coconut (6.9%), honey (2.6%), milk fat, almonds (1.3%), emulsifier (soya lecithin), egg white, flavouring. milk chocolate contains: cocoa solids 28% minimum. milk solids 14% minimum. may contain other nuts.
# 370041                                                                                                                                                                                                                                                                                                                                            almondmilk (water,almonds), cane sugar, pea protein, less than 1% of: dutch cocoa (processed with alkali),  flavors, calcium phosphate, sea salt, pectin, gellan gum,sunflower lecithin.
# 368874                                                                                                                                                                                                                                                                                                                                      filtered water, almondmilk (water,almonds), cane sugar, pea protein, less than 1% of:  flavors, calcium phosphate, vanilla extract, sea salt, pectin, gellan gum, sunglower lecithin,cinnamon.
# 1807326                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            instant nonfat dry milk, vitamins a,d3.
#
#          branded_food_category
# 291510   Milk/Milk Substitutes
# 294654   Milk/Milk Substitutes
# 572082   Milk/Milk Substitutes
# 291512   Milk/Milk Substitutes
# 1807282  Milk/Milk Substitutes
# 856239   Milk/Milk Substitutes
# 369253   Milk/Milk Substitutes
# 370041   Milk/Milk Substitutes
# 368874   Milk/Milk Substitutes
# 1807326  Milk/Milk Substitutes

# %%
milk_ids = [
    1781936, 
    2482086, 
    1067713, 
    1391783, 
    1843786, 
    521270, 
    499797, 
    1438042,
    1393720,
    1770827, 
    1152271, 
    865930, 
    2392598,
    1582256, 
    1293194,
    605948,
]
branded_data[deserving_columns][branded_data.fdc_id.isin(milk_ids)]
# Out:
#           fdc_id                             brand_owner  \
# 187854    499797            Thai Coconut Public Co.,Ltd.
# 208873    521270   First International Health Foods Ltd.
# 291512    605948                          Conagra Brands
# 409793    865930                          Danone US, LLC
# 505209   1067713            Eagle Family Foods Group LLC
# 561262   1152271  BJ's Wholesale Club / Corporate Brands
# 701103   1293194                         Ahold Usa, Inc.
# 793625   1391783                     Maple Hill Creamery
# 795544   1393720                      Steuben Foods Inc.
# 838839   1438042                  Topco Associates, Inc.
# 982501   1582256                            Meijer, Inc.
# 1156699  1770827            New Generation Exclusive,Inc
# 1167793  1781936                        Lala U.S., Inc.
# 1229045  1843786               PepsiCo, Inc. (CytoSport)
# 1687381  2392598                          Danone US, LLC
# 1776869  2482086                   Piggly Wiggly Company
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ingredients  \
# 187854                                                                                                                                                                                                                                                                                                                                                                                              COCONUT WATER, COCONUT EXTRACTED, NATURAL CANE SUGAR, STRAWBERRY PUREE, BANANA SYRUP, NATURAL BANANA FLAVOR, SUCROSE ESTERS OF FATTY ACID, NATURAL STRAWBERRY FLAVOR, PECTIN, GUAR GUM, FD&C RED, XANTHAN GUM, STEVIA, WATER.
# 208873                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ORGANIC COCONUT EXTRACT, WATER, ORGANIC GUAR GUM
# 291512                                                                               Water, Soybean Oil, Cheddar Cheese (Cheese [Cultured Pasteurized Milk, Salt, Enzymes], Water, Salt, Potassium Sorbate), Modified Corn Starch, Maltodextrin, Nonfat Dry Milk, Butter (Cream, Salt), Less than 2% of: Corn Starch, Cheese Blend (Cheddar, Granular, Semisoft, and Blue Cheese [Pasteurized Milk, Cheese Cultures, Salt, Enzymes], Water, Salt, Lactic Acid, Vinegar, Citric Acid, Natural Flavor), Salt, Sodium Phosphate, Distilled Vinegar, DATEM, Lactic Acid, Autolyzed Yeast Extract, Yellow 6, Yellow 5. CONTAINS: MILK.
# 409793                                                                                                                                                                                                                                                                                                                                                       INGREDIENTS: ORGANIC ALMONDMILK (FILTERED WATER, ORGANIC ALMONDS), SALT, VITAMIN AND MINERAL BLEND (CALCIUM CARBONATE, VITAMIN E ACETATE, VITAMIN A PALMITATE, VITAMIN B2), ORGANIC LOCUST BEAN GUM, ORGANIC NATURAL FLAVOR, ORGANIC SUNFLOWER LECITHIN, GELLAN GUM.
# 505209                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               MILK, SUGAR.
# 561262                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          FILTERED WATER, ORGANIC ALMONDS, LESS THAN 2%: CALCIUM (CALCIUM CARBONATE), SEA SALT, GELLAN GUM.
# 701103                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             WATER, COCONUT MILK, GUAR GUM.
# 793625                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ORGANIC REDUCED FAT MILK, ORGANIC CANE SUGAR, ORGANIC DUTCH COCOA, SALT, ORGANIC VANILLA EXTRACT, GELLAN GUM, VITAMIN A PALMITATE, VITAMIN D3
# 795544                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   FILTERED WATER, WALNUTS.
# 838839                                                                                                                                                                                                                                                                                                                                                                        OAT BEVERAGE (FILTERED WATER, OATS), CONTAINS 2% OR LESS OF: HI OLEIC SUNFLOWER OIL, CALCIUM CARBONATE, TRICALCIUM PHOSPHATE, SEA SALT, GELLAN GUM, POTASSIUM PHOSPHATE, VITAMIN A PALMITATE, ERGOCALCIFEROL (VITAMIN D2), RIBOFLAVIN, VITAMIN B12.
# 982501                                                                                                                                                                                                                                                                                                                                                                                                                ORGANIC SOYMILK (FILTERED WATER, ORGANIC SOYBEANS), ORGANIC CANE SUGAR, CALCIUM CARBONATE, SEA SALT, NATURAL FLAVORS, GELLAN GUM, VITAMIN A PALMITATE, VITAMIN D2, RIBOFLAVIN (VITAMIN B2) AND VITAMIN B12.
# 1156699                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             FILTERED WATER, COCONUT MILK* (COCONUT CREAM*, WATER), DATE NECTAR*, CACAO*, CINNAMON*, TURMERIC*, CARDAMOM*.
# 1167793                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         MILK, VITAMIN D3.
# 1229045  WHEY PROTEIN CONCENTRATE, MILK PROTEIN ISOLATE, CALCIUM CASEINATE, MALTODEXTRIN, RESISTANT MALTODEXTRIN (FIBERSOL-2), SODIUM CASEINATE, SUNFLOWER OIL, CANOLA OIL, MEDIUM CHAIN TRIGLYCERIDES, ORGANIC OAT FIBER, NATURAL AND ARTIFICIAL FLAVORS, CHOCOLATE COOKIE PIECES (MILK PROTEIN ISOLATE, CHICORY ROOT FIBER, PALM OIL, SUGAR, ALKALIZED COCOA POWDER, GROUND FLAX SEED, SUNFLOWER LECITHIN, NATURAL FLAVOR), CALCIUM PHOSPHATE, LESS THAN 1% OF: POTASSIUM CHLORIDE, MAGNESIUM OXIDE, SUCRALOSE, MONO- AND DIGLYCERIDES, TOCOPHEROLS, ACESULFAME POTASSIUM, ASCORBIC ACID, VITAMIN A PALMITATE, CHOLECALCIFEROL.
# 1687381                                                                                                                                                                                                                                                                                           CASHEWMILK (FILTERED WATER, CASHEWS), CONTAINS 2% OR LESS OF: CANOLA OIL, VITAMIN AND MINERAL BLEND (CALCIUM PHOSPHATE, MAGNESIUM PHOSPHATE, CALCIUM CARBONATE, L-SELENOMETHIONINE [SELENIUM], VITAMIN A ACETATE, VITAMIN D2, ZINC OXIDE, VITAMIN B12), GUAR GUM, KOSHER SEA SALT, LOCUST BEAN GUM, GELLAN GUM, NATURAL FLAVOR.
# 1776869                                                                                                                                                                                                                                                                                                                                                                                                                                                                                CULTURE LOWFAT MILK, NONFAT MILK, FOOD STARCH, SALT, LOCUST BEAN GUM, CARRAGEENAN, MONO AND DIGLYCERIDES, VITAMIN A PALMITATE, VITAMIN D3.
#
#          branded_food_category
# 187854        Plant Based Milk
# 208873        Plant Based Milk
# 291512   Milk/Milk Substitutes
# 409793        Plant Based Milk
# 505209                    Milk
# 561262        Plant Based Milk
# 701103        Plant Based Milk
# 793625                    Milk
# 795544        Plant Based Milk
# 838839        Plant Based Milk
# 982501        Plant Based Milk
# 1156699       Plant Based Milk
# 1167793                   Milk
# 1229045                   Milk
# 1687381       Plant Based Milk
# 1776869                   Milk

# %%
#nutrient_info = pd.read_csv('../data/raw/FoodData_Central_csv_2023-04-20/nutrient.csv')

# %%
# We want to use the ingredients for the model,
# so we discard records that dont contain ingredients. 
branded_data = branded_data[branded_data.ingredients.notna()]

# We are getting all the information that has nutrient information 
branded_data = branded_data[branded_data.fdc_id.isin(nutrient_data.fdc_id)]

# We want only the same products ('gtin_upc' makes the deal)
clean_gtin_upc = branded_data.gtin_upc.astype('string')\
.str.replace('-', '')\
.str.replace(' ', '')\
.str.replace('X', '')\
.str.replace('>', '')\
.str.replace('`', '')\
.str.replace('.', '')
gtin_upc_conditions = clean_gtin_upc.str.isdigit()

branded_data['clean_gtin_upc'] = clean_gtin_upc

branded_data = branded_data[gtin_upc_conditions]

# Lets sort the dataframe 
branded_data['available_date'] = pd.to_datetime(branded_data['available_date'])
branded_data.sort_values('available_date', inplace=True)
branded_data_reduced = branded_data.groupby('clean_gtin_upc').last().reset_index()

# %%
branded_data_reduced[['fdc_id', 'ingredients', 'branded_food_category']]
# Out:
#          fdc_id  \
# 0        555505
# 1       1055419
# 2       1055431
# 3       1055439
# 4       1055441
# ...         ...
# 564439   555751
# 564440   555737
# 564441  1129231
# 564442  2067237
# 564443  2067243
#
#                                                                             ingredients  \
# 0                    ORGANIC BLUE CORN, ORGANIC SUNFLOWER OIL, SEA SALT, TRACE OF LIME.
# 1       ROASTED PEANUTS (PEANUTS, PEANUT OR CANOLA OIL, SALT), SESAME STICKS (UNBLEA...
# 2       YOGURT RAISINS, TAMARI ROASTED ALMONDS, ORGANIC TAMARI ROASTED SOY NUTS, DAR...
# 3       ORGANIC ROLLED OATS, ORGANIC EVAPORATED CANE JUICE, ORGANIC QUINOA FLAKES, O...
# 4       DRY ROASTED ALMONDS, HATCH GREEN CHILE SEASONING (ORGANIC CHEDDAR CHEESE POW...
# ...                                                                                 ...
# 564439  PORK, WATER, SALT, DEXTROSE, SODIUM LACTATE, SODIUM PHOSPHATES, DEHYDRATED P...
# 564440  PORK, WATER, SALT, DEXTROSE, SODIUM LACTATE, SODIUM PHOSPHATES, DEHYDRATED P...
# 564441  SUGAR, BUTTER(MILK), WHEAT FLOUR(WHEAT FLOUR, MALTED BARLEY FLOUR), CHOCOLAT...
# 564442  TOMATO PASTE, DISTILLED VINEGAR, WATER, HIGH FRUCTOSE CORN SYRUP, HORSERADIS...
# 564443    DISTILLED VINEGAR, WATER, MUSTARD SEED, SALT, DEHYDRATED HORSERADISH, SPICES.
#
#                            branded_food_category
# 0                       Chips, Pretzels & Snacks
# 1                                   Other Snacks
# 2       Popcorn, Peanuts, Seeds & Related Snacks
# 3                                         Cereal
# 4       Popcorn, Peanuts, Seeds & Related Snacks
# ...                                          ...
# 564439                         Cooked & Prepared
# 564440             Pepperoni, Salami & Cold Cuts
# 564441                        Cookies & Biscuits
# 564442         Oriental, Mexican & Ethnic Sauces
# 564443      Ketchup, Mustard, BBQ & Cheese Sauce
#
# [564444 rows x 3 columns]

# %%
#branded_data[branded_data.clean_gtin_upc=='000000000000']
nutrient_data[nutrient_data.fdc_id==555505].merge(nutrient_info, left_on='nutrient_id', right_on='id')
# Out:
#        id_x  fdc_id  nutrient_id  amount  data_points  derivation_id  min  \
# 0   4320669  555505         1008  500.00          NaN           70.0  NaN
# 1   4320673  555505         1257    0.00          NaN           70.0  NaN
# 2   4320667  555505         1004   25.00          NaN           70.0  NaN
# 3   4320668  555505         1005   67.86          NaN           70.0  NaN
# 4   4320674  555505         1258    3.57          NaN           70.0  NaN
# 5   4320675  555505         1292    5.36          NaN           70.0  NaN
# 6   4320676  555505         1293   10.71          NaN           70.0  NaN
# 7   4320672  555505         1093  286.00          NaN           70.0  NaN
# 8   4320670  555505         2000    0.00          NaN           70.0  NaN
# 9   4320671  555505         1079    3.60          NaN           70.0  NaN
# 10  4320666  555505         1003    7.14          NaN           70.0  NaN
# 11  2963432  555505         1162    0.00          NaN           75.0  NaN
# 12  2963429  555505         1087  143.00          NaN           75.0  NaN
# 13  2963430  555505         1089    1.29          NaN           75.0  NaN
# 14  2963431  555505         1104    0.00          NaN           75.0  NaN
# 15  2963433  555505         1253    0.00          NaN           75.0  NaN
#
#     max  median  loq footnote  min_year_acquired  id_y  \
# 0   NaN     NaN  NaN      NaN                NaN  1008
# 1   NaN     NaN  NaN      NaN                NaN  1257
# 2   NaN     NaN  NaN      NaN                NaN  1004
# 3   NaN     NaN  NaN      NaN                NaN  1005
# 4   NaN     NaN  NaN      NaN                NaN  1258
# 5   NaN     NaN  NaN      NaN                NaN  1292
# 6   NaN     NaN  NaN      NaN                NaN  1293
# 7   NaN     NaN  NaN      NaN                NaN  1093
# 8   NaN     NaN  NaN      NaN                NaN  2000
# 9   NaN     NaN  NaN      NaN                NaN  1079
# 10  NaN     NaN  NaN      NaN                NaN  1003
# 11  NaN     NaN  NaN      NaN                NaN  1162
# 12  NaN     NaN  NaN      NaN                NaN  1087
# 13  NaN     NaN  NaN      NaN                NaN  1089
# 14  NaN     NaN  NaN      NaN                NaN  1104
# 15  NaN     NaN  NaN      NaN                NaN  1253
#
#                                   name unit_name  nutrient_nbr     rank
# 0                               Energy      KCAL         208.0    300.0
# 1             Fatty acids, total trans         G         605.0  15400.0
# 2                    Total lipid (fat)         G         204.0    800.0
# 3          Carbohydrate, by difference         G         205.0   1110.0
# 4         Fatty acids, total saturated         G         606.0   9700.0
# 5   Fatty acids, total monounsaturated         G         645.0  11400.0
# 6   Fatty acids, total polyunsaturated         G         646.0  12900.0
# 7                           Sodium, Na        MG         307.0   5800.0
# 8         Sugars, total including NLEA         G         269.0   1510.0
# 9                 Fiber, total dietary         G         291.0   1200.0
# 10                             Protein         G         203.0    600.0
# 11      Vitamin C, total ascorbic acid        MG         401.0   6300.0
# 12                         Calcium, Ca        MG         301.0   5300.0
# 13                            Iron, Fe        MG         303.0   5400.0
# 14                       Vitamin A, IU        IU         318.0   7500.0
# 15                         Cholesterol        MG         601.0  15700.0

# %%
nutrient_info
# Out:
#        id                                        name unit_name  nutrient_nbr  \
# 0    2047            Energy (Atwater General Factors)      KCAL         957.0
# 1    2048           Energy (Atwater Specific Factors)      KCAL         958.0
# 2    1001                                      Solids         G         201.0
# 3    1002                                    Nitrogen         G         202.0
# 4    1003                                     Protein         G         203.0
# ..    ...                                         ...       ...           ...
# 469  2061                         Ergosta-7,22-dienol        MG           NaN
# 470  2062                          Ergosta-5,7-dienol        MG           NaN
# 471  2063                                  Verbascose         G           NaN
# 472  2064                            Oligosaccharides        MG           NaN
# 473  2065  Low Molecular Weight Dietary Fiber (LMWDF)         G         293.4
#
#         rank
# 0      280.0
# 1      290.0
# 2      200.0
# 3      500.0
# 4      600.0
# ..       ...
# 469  16211.0
# 470  16211.0
# 471   2450.0
# 472   2250.0
# 473   1306.0
#
# [474 rows x 5 columns]

# %%
branded_data['ingredients_manipulation'] = branded_data.ingredients
branded_data['ingredients_manipulation'] = branded_data.ingredients_manipulation.str.lower().str.replace('ingredients:', '')
branded_data['ingredients_manipulation'] = branded_data.ingredients_manipulation.str.replace('made of:', '').str.replace('*', '').str.replace('.', '')
branded_data['semicolon_count'] = branded_data.ingredients_manipulation.str.count(':')

# %%
branded_data
# Out:
#           fdc_id      brand_name      gtin_upc  \
# 0        1105904             NaN   27000612323
# 1        1105905             NaN   51000198808
# 2        1105906             NaN   51000213273
# 3        1105907             NaN   51000213303
# 4        1105908             NaN   51000224637
# ...          ...             ...           ...
# 1845292  2554910  LIFESTYLEFOODS  898425002682
# 1845293  2554911       VITA COCO  898999012858
# 1845294  2554912        CHANEY'S  899503001443
# 1845295  2554913   TATTOOED CHEF  899764001527
# 1845296  2554914      ALIMENTIAS  899938002886
#
#                             branded_food_category  \
# 0                                     Oils Edible
# 1                           Herbs/Spices/Extracts
# 2                                  Prepared Soups
# 3                                  Prepared Soups
# 4                           Herbs/Spices/Extracts
# ...                                           ...
# 1845292       Pickles, Olives, Peppers & Relishes
# 1845293                         Plant Based Water
# 1845294                                      Milk
# 1845295                Frozen Patties and Burgers
# 1845296  Popcorn, Peanuts, Seeds & Related Snacks
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ingredients  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Vegetable Oil
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 INGREDIENTS: BEEF STOCK, CONTAINS LESS THAN 2% OF: MIREPOIX (CARROTS, CELERY, ONIONS), SALT, NATURAL FLAVORING, YEAST EXTRACT, CANE SUGAR.
# 2                                                                                                                                                                                                                                                                                                                                                                                     INGREDIENTS: CLAM STOCK, POTATOES, CLAMS, CREAM, VEGETABLE OIL (CORN, CANOLA, AND/OR SOYBEAN), CELERY, CONTAINS LESS THAN 2% OF: MODIFIED FOOD STARCH, SALT, WHEAT FLOUR, SOY PROTEIN CONCENTRATE, UNCURED SMOKED BACON PIECES-NO NITRATES OR NITRITES ADDED, EXCEPT FOR THOSE NATURALLY OCCURRING IN SEA SALT (PORK, WATER, SEA SALT, SUGAR), DRIED ONIONS, SPICES, SODIUM PHOSPHATE, FLAVORING, CLAM EXTRACT, SUCCINIC ACID, SUGAR, SOY LECITHIN, SOY SAUCE (SOYBEANS, WHEAT, SALT).CONTAINS: COD, WHEAT, MILK, SOY.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                           INGREDIENTS: WATER, CREAM, BROCCOLI, CELERY, VEGETABLE OIL (CORN, CANOLA, AND/OR SOYBEAN), MODIFIED FOOD STARCH, CHEDDAR CHEESE** (CHEDDAR CHEESE [CULTURED MILK, SALT, ENZYMES], WHEY, SALT, SODIUM PHOSPHATE), CONTAINS LESS THAN 2% OF: BUTTER, PARMESAN AND CHEDDAR CHEESE (MILK, CULTURES, SALT, ENZYMES), WHEAT FLOUR, SALT, POTATOES**, ONIONS**, SOY PROTEIN CONCENTRATE, ROASTED GARLIC**, ANNATTO EXTRACT FOR COLOR, SOY LECITHIN.  **DRIEDCONTAINS: WHEAT, MILK, SOY.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              INGREDIENTS: CHICKEN STOCK, CONTAINS LESS THAN 2% OF: YEAST EXTRACT, DEHYDRATED CHICKEN, NATURAL FLAVORING, CARROT JUICE CONCENTRATE, CELERIAC JUICE CONCENTRATE, CHICKEN FAT, ONION EXTRACT.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 1845292  ARCADIAN HARVEST LETTUCE (BLEND OF LEAF LETTUCES), RANCH DRESSING (BUTTERMILK [CULTURED PASTEURIZED PART-SKIM MILK, NONFAT MILK POWDER, SALT], SOYBEAN OIL AND/OR CANOLA OIL, WATER, EGG YOLK, NATURAL FLAVORS, CONTAINS LESS THAN 2% OF: DEHYDRATED GARLIC, DEHYDRATED ONION, DEHYDRATED PARSLEY, DISTILLED VINEGAR, GLUCONO DELTA LACTONE, PROPYLENE GLYCOL ALGINATE, SALT, SODIUM CITRATE, SPICES [CONTAINS MUSTARD], SUGAR, TITANIUM DIOXIDE [COLOR], XANTHAN GUM), TOMATOES, RED CABBAGE, HAM WITH WATER AND SMOKE FLAVOR ADDED (PORK [CURED WITH: WATER, DEXTROSE, SALT, SODIUM PHOSPHATE, SODIUM ERYTHORBATE, NATURAL SMOKE FLAVOR, SODIUM NITRITE]), WHITE TURKEY (WHITE TURKEY, WATER, MODIFIED FOOD STARCH, SALT, DEXTROSE, SODIUM PHOSPHATE), CHEDDAR CHEESE (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES, ANNATTO, VEGETABLE COLOR [IF COLORED], CORN STARCH [ANTI-CAKING AGENT]).
# 1845293                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                COCONUT WATER FROM CONCENTRATE (WATER, COCONUT WATER CONCENTRATE), SUGAR, NATURAL PINEAPPLE FLAVOR WITH OTHER NATURAL FLAVORS, COCONUT PUREE, VITAMIN C (ASCORBIC ACID), GELLAN GUM*.
# 1845294                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               WHOLE MILK, VITAMIN D3
# 1845295                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            CAULIFLOWER, CORN FLOUR, GRANA PADANO CHEESE (MILK, SALT, RENNET, LYSOZYME PROTEIN [EGG] AS PRESERVATIVE), DEHYDRATED POTATO, WATER, SUNFLOWER OIL, TAPIOCA STARCH, SALT, CHIVES, SPICES.
# 1845296                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           MARCONA ALMONDS (ORIGIN: SPAIN), TRUFFLE SALT (SEA SALT, TRUFFE, WHITE TRUFFLE ESSENCE), OLIVE OIL (WHITE TRUFFLE ESSENCE), SUNFLOWER OIL.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ingredients_manipulation  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             vegetable oil
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              beef stock, contains less than 2% of: mirepoix (carrots, celery, onions), salt, natural flavoring, yeast extract, cane sugar
# 2                                                                                                                                                                                                                                                                                                                                                                                                   clam stock, potatoes, clams, cream, vegetable oil (corn, canola, and/or soybean), celery, contains less than 2% of: modified food starch, salt, wheat flour, soy protein concentrate, uncured smoked bacon pieces-no nitrates or nitrites added, except for those naturally occurring in sea salt (pork, water, sea salt, sugar), dried onions, spices, sodium phosphate, flavoring, clam extract, succinic acid, sugar, soy lecithin, soy sauce (soybeans, wheat, salt)contains: cod, wheat, milk, soy
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                   water, cream, broccoli, celery, vegetable oil (corn, canola, and/or soybean), modified food starch, cheddar cheese (cheddar cheese [cultured milk, salt, enzymes], whey, salt, sodium phosphate), contains less than 2% of: butter, parmesan and cheddar cheese (milk, cultures, salt, enzymes), wheat flour, salt, potatoes, onions, soy protein concentrate, roasted garlic, annatto extract for color, soy lecithin  driedcontains: wheat, milk, soy
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           chicken stock, contains less than 2% of: yeast extract, dehydrated chicken, natural flavoring, carrot juice concentrate, celeriac juice concentrate, chicken fat, onion extract
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 1845292  arcadian harvest lettuce (blend of leaf lettuces), ranch dressing (buttermilk [cultured pasteurized part-skim milk, nonfat milk powder, salt], soybean oil and/or canola oil, water, egg yolk, natural flavors, contains less than 2% of: dehydrated garlic, dehydrated onion, dehydrated parsley, distilled vinegar, glucono delta lactone, propylene glycol alginate, salt, sodium citrate, spices [contains mustard], sugar, titanium dioxide [color], xanthan gum), tomatoes, red cabbage, ham with water and smoke flavor added (pork [cured with: water, dextrose, salt, sodium phosphate, sodium erythorbate, natural smoke flavor, sodium nitrite]), white turkey (white turkey, water, modified food starch, salt, dextrose, sodium phosphate), cheddar cheese (pasteurized milk, cheese cultures, salt, enzymes, annatto, vegetable color [if colored], corn starch [anti-caking agent])
# 1845293                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 coconut water from concentrate (water, coconut water concentrate), sugar, natural pineapple flavor with other natural flavors, coconut puree, vitamin c (ascorbic acid), gellan gum
# 1845294                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              whole milk, vitamin d3
# 1845295                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            cauliflower, corn flour, grana padano cheese (milk, salt, rennet, lysozyme protein [egg] as preservative), dehydrated potato, water, sunflower oil, tapioca starch, salt, chives, spices
# 1845296                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           marcona almonds (origin: spain), truffle salt (sea salt, truffe, white truffle essence), olive oil (white truffle essence), sunflower oil
#
#          semicolon_count
# 0                      0
# 1                      1
# 2                      2
# 3                      2
# 4                      1
# ...                  ...
# 1845292                2
# 1845293                0
# 1845294                0
# 1845295                0
# 1845296                1
#
# [1839904 rows x 7 columns]

# %%
print(f'There are {branded_data.branded_food_category.nunique()} categories in this dataset')
# Out:
# There are 428 categories in this dataset

# %%
branded_data.branded_food_category.value_counts().head(30)
# Out:
# branded_food_category
# Popcorn, Peanuts, Seeds & Related Snacks           87555
# Candy                                              83980
# Cheese                                             76177
# Ice Cream & Frozen Yogurt                          58400
# Cookies & Biscuits                                 50611
# Chips, Pretzels & Snacks                           47527
# Breads & Buns                                      45169
# Pickles, Olives, Peppers & Relishes                42293
# Fruit & Vegetable Juice, Nectars & Fruit Drinks    39468
# Chocolate                                          37835
# Snack, Energy & Granola Bars                       37812
# Cakes, Cupcakes, Snack Cakes                       36323
# Cereal                                             35036
# Yogurt                                             34718
# Seasoning Mixes, Salts, Marinades & Tenderizers    32253
# Soda                                               31713
# Other Snacks                                       29571
# Pasta by Shape & Type                              29355
# Dips & Salsa                                       29057
# Ketchup, Mustard, BBQ & Cheese Sauce               28645
# Salad Dressing & Mayonnaise                        26624
# Wholesome Snacks                                   25708
# Water                                              24719
# Frozen Dinners & Entrees                           23918
# Pre-Packaged Fruit & Vegetables                    23296
# Milk                                               21642
# Frozen Appetizers & Hors D'oeuvres                 20626
# Frozen Vegetables                                  20033
# Canned Vegetables                                  19996
# Pepperoni, Salami & Cold Cuts                      19630
# Name: count, dtype: int64

# %%
# We have MAAANY Bread and Buns

# %%
def get_similarities_of_dataset(data, category, sample_size, id_col='fdc_id', random_state=42):
    """
    """
    sample_data = data[category].copy()[[id_col]].sample(sample_size,random_state=random_state)
    sample_data[f'{id_col}2'] = [sample_data[id_col].to_list()]*len(sample_data)
    sample_data_result = sample_data.explode(f'{id_col}2', ignore_index=True)
    sample_data_result['similarity'] = 1
    sample_data.reset_index(drop=True, inplace=True)
    return sample_data, sample_data_result

def get_differences_between_datasets(data0, data1, id_col):
    data_a = pd.concat([data0.drop(f'{id_col}2', axis=1), data1.drop(id_col, axis=1)], axis=1)
    data_b = pd.concat([data1.drop(f'{id_col}2', axis=1), data0.drop(id_col, axis=1)], axis=1)
    data = pd.concat([data_a, data_b])
    data_res = data.explode(f'{id_col}2', ignore_index=True)
    data_res['similarity'] = 0
    return data_res
    

def get_simple_dataset(food_dict, sample_size=100, categ1=None, categ2=None):
    # Similarities for category 1 (asume everything in category is the same):
    food0, food0_res = get_similarities_of_dataset(food_dict, categ1, sample_size=sample_size, id_col='fdc_id')
    # Similarities for category 2 (asume everything in category is the same):
    food1, food1_res = get_similarities_of_dataset(food_dict, categ2, sample_size=sample_size, id_col='fdc_id')
    # Differences for categories: (asume everything outside category is not the same):
    food2_res = get_differences_between_datasets(food0, food1, id_col='fdc_id')
    # Merge results
    results = pd.concat([food0_res, food1_res, food2_res], axis=0)
    return results

# %%
# First we need to create a dictionary for this functions to work.
food_dict = {}
food_dict['bread'] = branded_data[branded_data.branded_food_category == 'Breads & Buns']
food_dict['yogurt'] = branded_data[branded_data.branded_food_category == 'Yogurt']
food_dict['soda'] = branded_data[branded_data.branded_food_category == 'Soda']
food_dict['cookies'] = branded_data[branded_data.branded_food_category == 'Cookies & Biscuits']
food_dict['cereal'] = branded_data[branded_data.branded_food_category == 'Cereal']

# %%
test_df = pd.concat([
    get_simple_dataset(food_dict, 10, 'bread', 'yogurt'),
    get_simple_dataset(food_dict, 10, 'bread', 'soda'),
    get_simple_dataset(food_dict, 10, 'bread', 'cookies'),
    get_simple_dataset(food_dict, 10, 'yogurt', 'cookies'),
    get_simple_dataset(food_dict, 10, 'soda', 'yogurt'),

]).drop_duplicates()

# %%
test_df
# Out:
#       fdc_id  fdc_id2  similarity
# 0    2037398  2037398           1
# 1    2037398  1557736           1
# 2    2037398  2374051           1
# 3    2037398  2138331           1
# 4    2037398  1249786           1
# ..       ...      ...         ...
# 195   544139  2335225           0
# 196   544139  1967840           0
# 197   544139   498542           0
# 198   544139  1363363           0
# 199   544139  1342906           0
#
# [1400 rows x 3 columns]

# %%
test_df[test_df.fdc_id==2530463]
# Out:
#       fdc_id  fdc_id2  similarity
# 10   2530463   793289           1
# 11   2530463  2530463           1
# 12   2530463  1684750           1
# 13   2530463  1325638           1
# 14   2530463  2191414           1
# 15   2530463   873892           1
# 16   2530463  2292401           1
# 17   2530463  1696147           1
# 18   2530463  1706760           1
# 19   2530463   544139           1
# 110  2530463  2037398           0
# 111  2530463  1557736           0
# 112  2530463  2374051           0
# 113  2530463  2138331           0
# 114  2530463  1249786           0
# 115  2530463  2480250           0
# 116  2530463  2397980           0
# 117  2530463   404971           0
# 118  2530463  2119542           0
# 119  2530463  2168557           0
# 10   2530463  1491205           0
# 11   2530463   504357           0
# 12   2530463   697500           0
# 13   2530463   429160           0
# 14   2530463  1239665           0
# 15   2530463  1857017           0
# 16   2530463   429031           0
# 17   2530463  1632972           0
# 18   2530463  1581385           0
# 19   2530463   604480           0
# 110  2530463  2453952           0
# 111  2530463  2083392           0
# 112  2530463  1646832           0
# 113  2530463  1391299           0
# 114  2530463  2117300           0
# 115  2530463  2335225           0
# 116  2530463  1967840           0
# 117  2530463   498542           0
# 118  2530463  1363363           0
# 119  2530463  1342906           0

# %%
branded_data[branded_data.fdc_id==2530463].ingredients_manipulation.str.split(',')
# Out:
# 1820845    [strawberry - cultured pasteurized grade a lowfat milk,  sugar,  strawberries,  modified cornstarch,  nonfat milk solids,  pectin,  natural flavors,  citric acid,  black carrot juice (color),  vitamin a palmitate,  vitamin d3, peach - cultured pasteurized grade a lowfat milk,  sugar,  peaches,  modified cornstarch,  nonfat milk solids,  pectin,  natural flavors,  citric acid,  annatto (color),  vitamin a palmitate,  vitamin d3]
# Name: ingredients_manipulation, dtype: object

# %%
branded_data[branded_data.fdc_id==2083392].ingredients_manipulation.str.split(',')
# Out:
# 1422943    [carbonated water,  high fructose corn syrup,  citric acid,  natural and artificial flavors,  fd&c yellow #6,  caramel color,  sodium benzoate.]
# Name: ingredients_manipulation, dtype: object

# %%
branded_data[branded_data.fdc_id==1696147].ingredients_manipulation.str.split(',')
# Out:
# 1089972    [lowfat yogurt (cultured pasteurized nonfat milk,  cream),  cane sugar,  water,  hazelnuts,  wheat flour,  wheat starch,  sunflower oil,  natural flavors,  milk,  milk protein,  coffee powder,  fruit pectin,  chocolate,  cocoa butter,  locust bean gum,  guar gum,  cinnamon,  lemon juice concentrate,  soy lecithin,  vanilla extract,  salt.]
# Name: ingredients_manipulation, dtype: object

# %% [markdown]
# The problem here is that the ingredients are not-structured which might be complicated. Also, there might no be information on the ingredients. One should look at the survey foods so gain all of this information.
